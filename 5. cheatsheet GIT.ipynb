# %% [markdown]
# # Install

# %% [markdown]
# ## 1. Git bash

# %% [markdown]
# ## 2. Github dekstop

# %% [markdown]
# ![GIT%20cheatsheet%20&%20workflow.png](attachment:GIT%20cheatsheet%20&%20workflow.png)

# %% [markdown]
# # GIT

# %% [markdown]
# ![GIT%20cheat%20sheet.jpg](attachment:GIT%20cheat%20sheet.jpg)

# %% [markdown]
# https://imron02.wordpress.com/2014/01/04/perintah-dasar-dasar-git-yang-sering-dipakai-menggunakan-git-versi-2/

# %% [markdown]
# - git pull ->>>>> git commit ->>>>> ubah dan edit
#
# - selesai ->>>>> git commiit ->>>> git push
