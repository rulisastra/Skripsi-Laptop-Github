# %%
import numpy as np

layer_2 = []
tanh = 5
layer_1 = 6
synapse_1 = 4

layer_2 = tanh(np.dot(layer_1,synapse_1))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-31cd384ad1e6> in <module>
#       6 synapse_1 = 4
#       7
# ----> 8 layer_2 = tanh(np.dot(layer_1,synapse_1))
#
# TypeError: 'int' object is not callable

# %% [markdown]
# # PERTANYAAN - PERTANYAAN -> jawaban
#
# 1. Knp pilih

# %% [markdown]
# ## PARAMETER
#
# cara hitung jumlah : weight (kalikan benang terhubung) + bias (jumlah neuron dituju)
# ![arsitektur.jpg](attachment:arsitektur.jpg)
# arsitektur pertama terdapat 3x4 weight + 4 bias dan 4x2 weight + 2 bias. Total adalah 26 parameter yang pada proses training akan mengalami perubahan untuk mendapatkan hasil yang terbaik. Sedangkan pada arsitektur kedua terdapat 41 parameter.
